# %%
import pandas as pd

# %% [markdown]
# read data from csv

# %%
dataframe=pd.read_csv('/content/educ_figdp_1_Data.csv')

# %% [markdown]
# Print data

# %%
df = pd.DataFrame(dataframe)

# %%
df.head()
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
# 3  Total public expenditure on education as % of ...  5.03                  e
# 4  Total public expenditure on education as % of ...  4.95                  e

# %%
dropna=df.dropna()

# %%
dropna
# Out:
#      TIME                            GEO  \
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# 5    2005  European Union (28 countries)
# 6    2006  European Union (28 countries)
# ..    ...                            ...
# 367  2007                       Slovakia
# 368  2008                       Slovakia
# 369  2009                       Slovakia
# 370  2010                       Slovakia
# 371  2011                       Slovakia
#
#                                               INDIC_ED Value  \
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# 5    Total public expenditure on education as % of ...  4.92
# 6    Total public expenditure on education as % of ...  4.91
# ..                                                 ...   ...
# ...

# %%
df
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED Value  \
# 0    Total public expenditure on education as % of ...     :
# 1    Total public expenditure on education as % of ...     :
# 2    Total public expenditure on education as % of ...  5.00
# 3    Total public expenditure on education as % of ...  5.03
# 4    Total public expenditure on education as % of ...  4.95
# ..                                                 ...   ...
# ...

# %%
import math

# %%
# Convert the 'Value' column to numeric type, coercing non-numeric values to NaN.
df['Value'] = pd.to_numeric(df['Value'], errors='coerce')

# Now you can fill the NaN values with the mean.
df['Value'].fillna(df['Value'].mean(), inplace=True)

# %%
df['Value'].fillna(df['Value'].mean())
# Out:
# 0      5.203989
# 1      5.203989
# 2      5.000000
# 3      5.030000
# 4      4.950000
#          ...
# 379    5.900000
# 380    6.100000
# 381    6.810000
# 382    6.850000
# 383    6.760000
# Name: Value, Length: 384, dtype: float64

# %%
df
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED     Value  \
# 0    Total public expenditure on education as % of ...  5.203989
# 1    Total public expenditure on education as % of ...  5.203989
# 2    Total public expenditure on education as % of ...  5.000000
# 3    Total public expenditure on education as % of ...  5.030000
# 4    Total public expenditure on education as % of ...  4.950000
# ..                                                 ...       ...
# ...

# %%
df['total']=0

# %%
df
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED     Value  \
# 0    Total public expenditure on education as % of ...  5.203989
# 1    Total public expenditure on education as % of ...  5.203989
# 2    Total public expenditure on education as % of ...  5.000000
# 3    Total public expenditure on education as % of ...  5.030000
# 4    Total public expenditure on education as % of ...  4.950000
# ..                                                 ...       ...
# ...

# %%
df.drop(columns='INDIC_ED')
# Out:
#      TIME                            GEO     Value Flag and Footnotes  total
# 0    2000  European Union (28 countries)  5.203989                NaN      0
# 1    2001  European Union (28 countries)  5.203989                NaN      0
# 2    2002  European Union (28 countries)  5.000000                  e      0
# 3    2003  European Union (28 countries)  5.030000                  e      0
# 4    2004  European Union (28 countries)  4.950000                  e      0
# ..    ...                            ...       ...                ...    ...
# 379  2007                        Finland  5.900000                NaN      0
# 380  2008                        Finland  6.100000                NaN      0
# 381  2009                        Finland  6.810000                NaN      0
# 382  2010                        Finland  6.850000                NaN      0
# 383  2011                        Finland  6.760000                NaN      0
#
# [384 rows x 5 columns]

# %%
df
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED     Value  \
# 0    Total public expenditure on education as % of ...  5.203989
# 1    Total public expenditure on education as % of ...  5.203989
# 2    Total public expenditure on education as % of ...  5.000000
# 3    Total public expenditure on education as % of ...  5.030000
# 4    Total public expenditure on education as % of ...  4.950000
# ..                                                 ...       ...
# ...

# %%
df
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED     Value  \
# 0    Total public expenditure on education as % of ...  5.203989
# 1    Total public expenditure on education as % of ...  5.203989
# 2    Total public expenditure on education as % of ...  5.000000
# 3    Total public expenditure on education as % of ...  5.030000
# 4    Total public expenditure on education as % of ...  4.950000
# ..                                                 ...       ...
# ...

# %%
sorted_df = df.sort_index(axis=1, ascending=True)

# %%
print(sorted_df)
# Out:
#     Flag and Footnotes                            GEO  \
# 0                  NaN  European Union (28 countries)
# 1                  NaN  European Union (28 countries)
# 2                    e  European Union (28 countries)
# 3                    e  European Union (28 countries)
# 4                    e  European Union (28 countries)
# ..                 ...                            ...
# 379                NaN                        Finland
# 380                NaN                        Finland
# 381                NaN                        Finland
# 382                NaN                        Finland
# 383                NaN                        Finland
#
#                                               INDIC_ED  TIME     Value  total
# 0    Total public expenditure on education as % of ...  2000  5.203989      0
# 1    Total public expenditure on education as % of ...  2001  5.203989      0
# 2    Total public expenditure on education as % of ...  2002  5.000000      0
# ...

# %%
df['Rank'] = df['TIME'].rank(axis=0, method='average')

# %%
df
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED     Value  \
# 0    Total public expenditure on education as % of ...  5.203989
# 1    Total public expenditure on education as % of ...  5.203989
# 2    Total public expenditure on education as % of ...  5.000000
# 3    Total public expenditure on education as % of ...  5.030000
# 4    Total public expenditure on education as % of ...  4.950000
# ..                                                 ...       ...
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot('TIME','Value',data=df,marker='o')
plt.xlabel('TIME')
plt.ylabel('Value')
plt.title("A simple line graph")
plt.show()
